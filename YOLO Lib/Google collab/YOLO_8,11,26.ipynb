# %%
! pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.5 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 21.3/107.7 GB disk)

# %%
# !yolo predict model=yolov8n.pt source='https://c8.alamy.com/comp/2J488B0/young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg'
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://c8.alamy.com/comp/2J488B0/young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg locally at young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg
# image 1/1 /content/young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg: 480x640 1 person, 1 cup, 2 chairs, 1 potted plant, 1 dining table, 1 laptop, 1 mouse, 1 cell phone, 218.4ms
# Speed: 8.5ms preprocess, 218.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolo11n.pt source='https://c8.alamy.com/comp/2J488B0/young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg'
# Out:
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Found https://c8.alamy.com/comp/2J488B0/young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg locally at young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg
# image 1/1 /content/young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg: 480x640 1 person, 1 cup, 1 chair, 1 potted plant, 1 dining table, 1 laptop, 199.2ms
# Speed: 7.9ms preprocess, 199.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolo26n.pt source='https://c8.alamy.com/comp/2J488B0/young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg'
# Out:
# ...
# Ultralytics 8.4.18 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# Found https://c8.alamy.com/comp/2J488B0/young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg locally at young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg
# image 1/1 /content/young-thoughtful-african-female-employee-looking-out-window-at-workplace-and-dreaming-about-vacation-2J488B0.jpg: 480x640 1 person, 1 cup, 1 chair, 2 potted plants, 1 dining table, 1 laptop, 174.5ms
# Speed: 6.0ms preprocess, 174.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
